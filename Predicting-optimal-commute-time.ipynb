# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import pandas as pd

# Daniela was here...


# Read the Parquet file into a DataFrame
weather = pd.read_parquet('data1.parquet', engine='pyarrow')

# Ensure the date column is in datetime format, replace 'your_date_column' with the actual column name
weather['YYYYMMDD'] = pd.to_datetime(weather['YYYYMMDD'])

# Filter the DataFrame for dates from 2016 onwards
weather = weather[weather['YYYYMMDD'] >= '2018-01-01']

# Define the new column names
column_mapping = {
    'STN': 'Station',
    'YYYYMMDD': 'Date',
    'H': 'Hour',
    'DD': 'WindDirection',
    'FH': 'WindSpeedAvg',
    'FF': 'WindSpeed',
    'FX': 'WindGust',
    'T': 'Temperature',
    'T10N': 'MinTemp10cm',
    'TD': 'DewPoint',
    'SQ': 'SunshineDuration',
    'Q': 'GlobalRadiation',
    'DR': 'PrecipitationDuration',
    'RH': 'PrecipitationAmount',
    'P': 'AirPressure',
    'VV': 'Visibility',
    'N': 'CloudCover',
    'U': 'Humidity',
    'WW': 'Weather',
    'IX': 'WeatherCode',
    'M': 'Fog',
    'R': 'Rain',
    'S': 'Snow',
    'O': 'Thunder',
    'Y': 'IceFormation'
}

# Rename the columns
weather.rename(columns=column_mapping, inplace=True)

# Display the filtered DataFrame
weather
# Out:
#         Station       Date   Hour WindDirection WindSpeedAvg WindSpeed  \
# 6378768     209 2018-01-01      1           210          180       180
# 6378769     209 2018-01-01      2           250          160       160
# 6378770     209 2018-01-01      3           260          160       160
# 6378771     209 2018-01-01      4           250          150       150
# 6378772     209 2018-01-01      5           250          140       140
# ...         ...        ...    ...           ...          ...       ...
# 9555883     391 2024-03-25     20            80           20        20
# 9555884     391 2024-03-25     21            80           20        20
# 9555885     391 2024-03-25     22            90           20        30
# 9555886     391 2024-03-25     23           100           30        30
# 9555887     391 2024-03-25     24           100           30        30
#
#         WindGust Temperature MinTemp10cm DewPoint  ... Visibility CloudCover  \
# 6378768      230                                   ...
# 6378769      210                                   ...
# 6378770      210                                   ...
# 6378771      200                                   ...
# 6378772      190                                   ...
# ...          ...         ...         ...      ...  ...        ...        ...
# 9555883       40          81                   -2  ...
# 9555884       40          73                   -3  ...
# 9555885       40          63                    3  ...
# 9555886       50          66                   -2  ...
# 9555887       50          63          49       -5  ...
#
#         Humidity Weather WeatherCode    Fog   Rain   Snow Thunder IceFormation
# 6378768                            6
# 6378769                            6
# 6378770                            6
# 6378771                            6
# 6378772                            6
# ...          ...     ...         ...    ...    ...    ...     ...          ...
# 9555883       55                   6
# 9555884       58                   6
# 9555885       65                   6
# 9555886       62                   6
# 9555887       61                   6
#
# [2539008 rows x 25 columns]

# %%
# Read the CSV file into a DataFrame
traffic = pd.read_csv('filtered highways traffic data.csv')

# Define the new column names
column_mapping = {
    'NLSitNummer': 'NLSituationNumber',
    'DatumFileBegin': 'DateFileStart',
    'DatumFileEind': 'DateFileEnd',
    'TijdFileBegin': 'TimeFileStart',
    'TijdFileEind': 'TimeFileEnd',
    'FileZwaarte': 'FileSeverity',
    'GemLengte': 'AvgLength',
    'FileDuur': 'FileDuration',
    'HectometerKop': 'HectometerHead',
    'HectometerStaart': 'HectometerTail',
    'RouteLet': 'RouteLetter',
    'RouteNum': 'RouteNumber',
    'RouteOms': 'RouteDescription',
    'hectometreringsrichting': 'HectometerDirection',
    'KopWegvakVan': 'HeadSegmentFrom',
    'KopWegvakNaar': 'HeadSegmentTo',
    'TrajVan': 'TrajectoryFrom',
    'TrajNaar': 'TrajectoryTo',
    'OorzaakGronddetail': 'CauseGroundDetail',
    'OorzaakVerloop': 'CauseProgress',
    'OorzaakCodeVerloop': 'CauseCodeProgress',
    'OorzaakCode': 'CauseCode',
    'Oorzaak_1': 'Cause1',
    'Oorzaak_2': 'Cause2',
    'Oorzaak_3': 'Cause3',
    'Oorzaak_4': 'Cause4'
}

# Rename the columns
traffic.rename(columns=column_mapping, inplace=True)

# Display the DataFrame try
traffic
# Out:
#         NLSituationNumber DateFileStart DateFileEnd TimeFileStart TimeFileEnd  \
# 0                 3589057    13/06/2023  13/06/2023      16:54:29    17:00:06
# 1                 3589060    13/06/2023  13/06/2023      16:54:29    16:56:05
# 2                 3589149    13/06/2023  13/06/2023      17:03:29    17:17:00
# 3                 3589235    13/06/2023  13/06/2023      17:13:29    17:15:04
# 4                 3589597    13/06/2023  13/06/2023      17:52:29    17:54:00
# ...                   ...           ...         ...           ...         ...
# 223098            2756631    08/04/2020  08/04/2020      12:58:00    15:06:07
# 223099            2756681    09/04/2020  09/04/2020      06:26:00    07:52:23
# 223100            2756680    09/04/2020  09/04/2020      06:25:00    06:31:41
# 223101            2756678    09/04/2020  09/04/2020      05:58:00    06:26:06
# 223102            2756682    09/04/2020  09/04/2020      06:31:00    07:02:04
#
#        FileSeverity  AvgLength FileDuration HectometerHead HectometerTail  \
# 0            13,480  2,400,000        5,617           45,6           47,9
# 1             5,120  3,200,000        1,600          166,5          169,7
# 2            32,867  2,432,000       13,517          115,9          118,1
# 3             3,325  2,100,000        1,583          155,5          157,6
# 4             5,612  3,700,000        1,517          164,5          168,2
# ...             ...        ...          ...            ...            ...
# 223098      405,883  3,168,076      128,117           90,6           92,6
# 223099      467,233  5,408,837       86,383           94,4           99,4
# 223100       13,367  2,000,000        6,683           68,9           70,9
# 223101      102,850  3,660,142       28,100           93,8           95,8
# 223102       62,200  2,002,146       31,067           69,1           71,1
#
#         ...    TrajectoryFrom          TrajectoryTo  \
# 0       ...        Ridderkerk             Europoort
# 1       ...            Arnhem                   Oss
# 2       ...  's-Hertogenbosch               Utrecht
# 3       ...            Arnhem                   Oss
# 4       ...            Arnhem                   Oss
# ...     ...               ...                   ...
# 223098  ...  's-Hertogenbosch               Utrecht
# 223099  ...          Nijmegen  Rotterdam Maasvlakte
# 223100  ...  's-Hertogenbosch               Utrecht
# 223101  ...         Gorinchem            Ridderkerk
# 223102  ...  's-Hertogenbosch               Utrecht
#
#                                CauseGroundDetail  \
# 0                Spitsfile (geen oorzaak gemeld)
# 1                Spitsfile (geen oorzaak gemeld)
# 2                Spitsfile (geen oorzaak gemeld)
# 3                Spitsfile (geen oorzaak gemeld)
# 4                Spitsfile (geen oorzaak gemeld)
# ...                                          ...
# 223098  Defecte vrachtwagen (met opruim/berging)
# 223099                  Er ligt rommel op de weg
# 223100                              Ongeval(len)
# 223101                  Er ligt rommel op de weg
# 223102                    Eerder(e) ongeval(len)
#
#                                             CauseProgress  \
# 0                 [Geen oorzaakcode opgegeven door VWM 6]
# 1                 [Geen oorzaakcode opgegeven door VWM 2]
# 2                [Geen oorzaakcode opgegeven door VWM 14]
# 3                 [Geen oorzaakcode opgegeven door VWM 2]
# 4                 [Geen oorzaakcode opgegeven door VWM 2]
# ...                                                   ...
# 223098  [Geen oorzaakcode opgegeven door VWM 3], [Opru...
# 223099  [Geen oorzaakcode opgegeven door VWM 0], [Er l...
# 223100       [Ongeval(len) 5], [Eerder(e) ongeval(len) 2]
# 223101                      [Er ligt rommel op de weg 28]
# 223102  [Geen oorzaakcode opgegeven door VWM 1], [Eerd...
#
#                  CauseCodeProgress CauseCode                           Cause1  \
# 0                            [000]         1  Spitsfile (geen oorzaak gemeld)
# 1                            [000]         1  Spitsfile (geen oorzaak gemeld)
# 2                            [000]         1  Spitsfile (geen oorzaak gemeld)
# 3                            [000]         1  Spitsfile (geen oorzaak gemeld)
# 4                            [000]         1  Spitsfile (geen oorzaak gemeld)
# ...                            ...       ...                              ...
# 223098  [000], [OCL], [HBD], [OCL]       HBD           Defecte vrachtwagen(s)
# 223099         [000], [SPL], [000]       SPL         Er ligt rommel op de weg
# 223100                [ACI], [ACA]       ACI                     Ongeval(len)
# 223101                       [SPL]       SPL         Er ligt rommel op de weg
# 223102                [000], [ACA]       ACA           Eerder(e) ongeval(len)
#
#                      Cause2                         Cause3            Cause4
# 0       Geen oorzaak gemeld                         Drukte  Hoge intensiteit
# 1       Geen oorzaak gemeld                         Drukte  Hoge intensiteit
# 2       Geen oorzaak gemeld                         Drukte  Hoge intensiteit
# 3       Geen oorzaak gemeld                         Drukte  Hoge intensiteit
# 4       Geen oorzaak gemeld                         Drukte  Hoge intensiteit
# ...                     ...                            ...               ...
# 223098  Defecte vrachtwagen   Incident (gestrand voertuig)          Incident
# 223099     Lading op de weg  Incident (obstakel op de weg)          Incident
# 223100              Ongeval                        Ongeval           Ongeval
# 223101     Lading op de weg  Incident (obstakel op de weg)          Incident
# 223102              Ongeval                        Ongeval           Ongeval
#
# [223103 rows x 26 columns]
